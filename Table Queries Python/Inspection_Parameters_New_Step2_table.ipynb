# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
conn = pymysql.connections.Connection(host="1.0.26.199",user='team_mis_jaipur',password='pC*KXv-MaAx4^]#M',db='misauto', port=3306)

# %%
Ins_query = """
    
    SELECT 
a.`vc_id`,
a.`Business_Type`,
a.`Inspection_Type`,
a.`Certification_Status`,
a.`Reg_No`,
a.`owner_id`,
a.`ce_start_date`,
a.`ce_end_date`,
a.`city`,
a.`state_name`,
a.`Inspected By`,
a.`make`,
a.`Model`,
a.`Reg_Year`,
a.`Mfg_Year`,
a.`Vehicle_Color`,
a.`fuel_type`,
a.`transmission`,
a.`owner`,
a.`QC_VerifedBy`,
a.`insurance_type`,
a.`clutch_pedal_operation`,
a.`engine_oil_pressure_light`,
a.`engine_coolant_temp_light`,
a.`engine_oil_quality`,
a.`engine_coolant_quality`,
a.`engine_exhaust_emission`,
a.`type_of_steering`,
a.`steering_wheel_adjustment`,
a.`steering_operation`,
a.`is_clutch_operation_satisfactory`,
a.`is_vibration_felt_on_steering_wheel`,
a.`is_abnormal_noise_from_suspension`,
a.`is_blow_by_engine_at_end_of_road_test`,
a.`engine_response_on_load`,
a.`engine_started`,
a.`steering_cylinder`,
a.`engine_sound`,
a.`engine_oil_level`,
a.`engine_coolant_level`,
a.`engine_performance`,
a.`engine_summary`,
a.`steering_comment`,
a.`steering_summary`,
a.`second_key`,
a.`Inspector_Name`,
a.`email`,
a.`road_test_status`,
a.`odometer_reading`,
a.`variant`,
a.`vehicle_condition`
FROM Inspection_Parameters_New a where DATE(a.ce_start_date)=DATE_SUB(CURDATE(),INTERVAL 1 DAY)
    
"""

# %%
cursor = conn.cursor()
cursor.execute(Ins_query)
# Out:
# 1209

# %%
data = cursor.fetchall()

# %%
column = [col[0] for col in cursor.description]

# %%
df = pd.DataFrame(data, columns = column)

# %%
df=df.assign(engine_sound=df['engine_sound'].str.split(',')).explode('engine_sound')
df=df.assign(engine_oil_level=df['engine_oil_level'].str.split(',')).explode('engine_oil_level')
df=df.assign(engine_coolant_level=df['engine_coolant_level'].str.split(',')).explode('engine_coolant_level')
df=df.assign(engine_performance=df['engine_performance'].str.split(',')).explode('engine_performance')
df=df.assign(engine_summary=df['engine_summary'].str.split(',')).explode('engine_summary')
df=df.assign(steering_comment=df['steering_comment'].str.split(',')).explode('steering_comment')
df=df.assign(steering_summary=df['steering_summary'].str.split(',')).explode('steering_summary')

# %%
df
# Out:
#         vc_id Business_Type Inspection_Type Certification_Status      Reg_No  \
# 0     1435606           C2D             C2D             Rejected  MH12QY7136
# 1     1439054           NCD             C2D             Rejected  GJ38BA8177
# 1     1439054           NCD             C2D             Rejected  GJ38BA8177
# 1     1439054           NCD             C2D             Rejected  GJ38BA8177
# 1     1439054           NCD             C2D             Rejected  GJ38BA8177
# ...       ...           ...             ...                  ...         ...
# 1206  1442972           NCD             C2D             Rejected  MH05DC2355
# 1206  1442972           NCD             C2D             Rejected  MH05DC2355
# 1206  1442972           NCD             C2D             Rejected  MH05DC2355
# 1207  1442974            DC        Warranty             Rejected  KA02MP6270
# 1208  1442975            DC        Warranty             Rejected   KA57S6798
#
# ...

# %%
db_connection_str = 'mysql+pymysql://team_mis_jaipur:pC*KXv-MaAx4^]#M@1.0.26.199/misauto'
db_connection = create_engine(db_connection_str)

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host = "1.0.26.199",
 user = "team_mis_jaipur",
 password = "pC*KXv-MaAx4^]#M",
 database = "misauto"
)

mycursor = mydb.cursor()
#mycursor.execute("TRUNCATE TABLE Inspection_Parameters_New")

# %%
df.to_sql('Inspection_Parameters_New_Step2', db_connection, if_exists = 'append', index = False)

# %%
import time
ts = time.time()
import datetime
st = datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
print(str(st)+" Inspection_Parameters_New_Step2_table")
print("*********************************")
# Out:
# 2022-03-29 10:05:49 Inspection_Parameters_New_Step2_table
# *********************************
